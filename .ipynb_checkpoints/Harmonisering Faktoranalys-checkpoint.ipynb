# %% [markdown]
# # <span style="color:mediumslateblue; font-family:freestyle script; font-size:5em">Harmonisering:</span> <br><span style="color:greenyellow; font-family:freestyle script; font-size:4em">Faktoranalys</span>
# ***

# %% [markdown]
# # Innehållsförteckning
# 1. [Importera bibliotek](#1)
# 2. [Importera data](#2)
# 3. [Faktoranalys](#3)
#     3.1 [Bartlett](#3.1)
#     3.2 [Shapiro-Wilk](#3.2)
#     3.3 [Rotation](#3.3)
#     3.4 [Antal faktorer](#3.4)
#     3.5 [Faktorladdningar](#3.5)
#     3.6 [Kumulativ varians](#3.6)
# 4. [Referenser](#4)
# ***

# %% [markdown]
# # <a id = "1">1. Importera bibliotek</a>
# De bibliotek som behövs i det här skriptet är **pandas**, **numpy**, **matplotlib.pyplot** och **FactorAnalyzer**.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from factor_analyzer import FactorAnalyzer

# %% [markdown]
# ***
# # <a id = "2">2. Importera data</a>
# Läs in data från excelfil.

# %%
data = pd.read_excel('SLOSH och LNU medelvärden och n per SSYK för harmonisering.xlsx')
data.head(5)
# Out:
#    SSYK  z670_mean  z670_count  z671_mean  z671_count  z672_mean  z672_count  \
# 0     9        1.4       319.0        1.6       318.0        1.1       319.0
# 1    11        2.0        11.0        2.0        11.0        1.2        11.0
# 2    12        1.8       123.0        1.8       123.0        1.0       123.0
# 3    13        1.4        22.0        1.8        22.0        1.1        22.0
# 4    14        NaN         NaN        NaN         NaN        NaN         NaN
#
#    z673_mean  z673_count  z674_mean  ...  Workinge_mean  Workinge_count  \
# 0        1.7         3.0        2.7  ...            4.0             1.0
# 1        2.5        11.0        2.5  ...            3.6            78.0
# 2        1.9       123.0        2.4  ...            3.5           280.0
# 3        1.8        22.0        2.0  ...            3.5           323.0
# 4        NaN         NaN        NaN  ...            3.8            96.0
#
#    Worklear_mean  Worklear_count  Workrepe_mean  Workrepe_count  Workhow_mean  \
# 0            4.0             1.0            4.0             1.0           4.0
# 1            3.5            78.0            2.5            78.0           3.6
# 2            3.4           280.0            2.5           285.0           3.7
# 3            3.4           322.0            2.6           326.0           3.7
# 4            3.6            96.0            2.4            97.0           3.7
#
#    Workhow_count  Workwhat_mean  Workwhat_count
# 0            1.0            2.0             1.0
# 1           78.0            3.2            78.0
# 2          284.0            3.3           285.0
# 3          326.0            3.3           326.0
# 4           96.0            3.2            96.0
#
# [5 rows x 69 columns]

# %% [markdown]
# Använd SSYK-variabeln som index och ta bort de variabler som visar antal observationer (alltså varannan variabel).

# %%
data = data.set_index('SSYK')

data = data[data.columns[::2]]  

data.head(5)
# Out:
#       z670_mean  z671_mean  z672_mean  z673_mean  z674_mean  z680_mean  \
# SSYK
# 9           1.4        1.6        1.1        1.7        2.7        3.4
# 11          2.0        2.0        1.2        2.5        2.5        3.3
# 12          1.8        1.8        1.0        1.9        2.4        3.3
# 13          1.4        1.8        1.1        1.8        2.0        3.3
# 14          NaN        NaN        NaN        NaN        NaN        NaN
#
#       z681_mean  z682_mean  z616_mean  z647_mean  ...  Workhard_mean  \
# SSYK                                              ...
# 9           3.8        4.4        1.0        5.7  ...            3.0
# 11          3.3        4.1        1.1        6.3  ...            2.9
# 12          4.4        4.1        1.0        6.0  ...            2.9
# 13          3.5        4.5        1.2        4.9  ...            2.8
# 14          NaN        NaN        NaN        NaN  ...            2.9
#
#       Workeffo_mean  Worktime_mean  Workcntr_mean  Workskil_mean  \
# SSYK
# 9               3.0            4.0            2.0            4.0
# 11              2.8            2.8            2.7            3.8
# 12              2.8            2.8            2.6            3.7
# 13              2.8            2.9            2.8            3.6
# 14              3.1            2.6            2.9            3.8
#
#       Workinge_mean  Worklear_mean  Workrepe_mean  Workhow_mean  Workwhat_mean
# SSYK
# 9               4.0            4.0            4.0           4.0            2.0
# 11              3.6            3.5            2.5           3.6            3.2
# 12              3.5            3.4            2.5           3.7            3.3
# 13              3.5            3.4            2.6           3.7            3.3
# 14              3.8            3.6            2.4           3.7            3.2
#
# [5 rows x 34 columns]

# %%
data.columns
# Out:
# Index(['z670_mean', 'z671_mean', 'z672_mean', 'z673_mean', 'z674_mean',
#        'z680_mean', 'z681_mean', 'z682_mean', 'z616_mean', 'z647_mean',
#        'z651_mean', 'z626_mean', 'z652_mean', 'z653_mean', 'z654_mean',
#        'z655_mean', 'z656_mean', 'z625_mean', 'z621_mean', 'z622_mean',
#        'Loadtime_mean', 'Interrup_mean', 'Morework_mean', 'Workfast_mean',
#        'Workhard_mean', 'Workeffo_mean', 'Worktime_mean', 'Workcntr_mean',
#        'Workskil_mean', 'Workinge_mean', 'Worklear_mean', 'Workrepe_mean',
#        'Workhow_mean', 'Workwhat_mean'],
#       dtype='object')

# %% [markdown]
# **2019-10-31**
# Under mötet beslutade vi att ta bort variablerna nedan ur faktoranalysen.

# %%
data = data.drop('z616_mean', axis = 1)

# %%
data = data.drop('z621_mean', axis = 1)

# %%
data = data.drop('z622_mean', axis = 1)

# %%
data = data.drop('z673_mean', axis = 1)

# %%
data = data.drop('z674_mean', axis = 1)

# %% [markdown]
# **2019-10-31**
# Vi beslutar att ta bort samtliga rader som innhåller åtminstone en tom cell (**NaN**, "missing"). Detta eftersom faktoranalysen delade upp variablerna från SLOSH och LNU. Det fanns alltså ingen faktor som hade laddningar från *både* SLOSH och LNU. När raderna tagits bort blev analysen mycket bättre i detta avseende. Samtliga faktorer har nu laddningar från både SLOSH- *och* LNU-variabler.

# %%
data = data.dropna()

# %% [markdown]
# ***
# # <a id = "3">3. Faktoranalys</a>
# Bartlett:s test genomförs för att se ifall det är lämpligt att utföra en faktoranalys på data. Vilken metod som är lämpligast för att utvinna faktorer avgörs av huruvida data är normalfördelad. Analysen kommer använda en oblique rotationsmetod. Antal faktorer som analysen ska omfatta fastställs med hjälp av Kaiser-kriteriet. Till sist analyseras faktorladdningarna och den kumulativa variansen.

# %% [markdown]
# ***
# ## <a id = "3.1">3.1 Bartlett</a>
# Tester visar ifall variablerna kovarierar över huvudtaget. Om resultat är statistiskt signifikant kovarierar variablerna och det är lämpligt att fortsätta med faktoranalysen
# [Läs mer om testet här](https://www.statisticshowto.datasciencecentral.com/bartletts-test/)

# %%
datatest = data.dropna()

from factor_analyzer.factor_analyzer import calculate_bartlett_sphericity  

chi_square_value,p = calculate_bartlett_sphericity(datatest)

chi_square_value, p

alpha = 0.05

if p > alpha:
    print('Variablerna samvarierar inte (H0)')
else:
    print('Variablerna samvarierar (förkasta H0)')
# Out:
# Variablerna samvarierar (förkasta H0)

# %% [markdown]
# ***
# ## <a id = "3.2">3.2 Shapiro-Wilk</a>
# Undersök huruvida data är normalfördelad. Testet som används är Shapiro-Wilk, nollhypotesen säger att data är normalfördelad.
#
# [Läs mer om testet här](https://www.statisticshowto.datasciencecentral.com/shapiro-wilk-test/)

# %%
from scipy.stats import shapiro

stat, p = shapiro(data)

alpha = 0.05

if p > alpha:
    print('Data verkar normalfördelad (H0)')
else:
    print('Data verkar inte normalfördelad (förkasta H0)')
# Out:
# Data verkar inte normalfördelad (förkasta H0)

# %% [markdown]
# ***
# ## <a id = "3.3">3.3 Rotation</a>
# Faktoranalysen kommer använda en oblique rotation. Ortogonal rotation är lämpligt då faktorerna inte är korrelerade med varandra. Oblique rotation tillåter att faktorerna är korrelerade. Läs mer om val av metod för rotation i "Best Practices in Exploratory Factor Analysis: Four Recommendations for Getting the Most From Your Analysis " av Anna B. Costello och Jason W. Osborne.
# >In the social sciences we generally expect some correlation among factors, since behavior is rarely partitioned into neatly packaged units that function independently of one another (s. 3)
#
# **2019-10-30**
# Michael förslår att vi istället börjar med varimax (ortogonal rotation) och PCA (för att utvinna faktorer).

# %% [markdown]
# ***
# ## <a id = "3.4">3.4 Antal faktorer</a>
# För att ta ställning till vilket antal faktorer som är lämpligt kommer Kaiser-kriteriet tillsammans med en Scree-plot användas. Kaiser-kritieriet säger att endast de faktorer med eigenvärde större än 1 är lämpliga. Börja med att inkludera ett stort antal faktorer.

# %%
fa = FactorAnalyzer(n_factors = 25, rotation = 'varimax', method = 'principal')

fa.fit(data)
# Out:
# FactorAnalyzer(bounds=(0.005, 1), impute='median', is_corr_matrix=False,
#         method='principal', n_factors=25, rotation='varimax',
#         rotation_kwargs={}, use_smc=True)

# %% [markdown]
# Ta fram egenvärden.

# %%
ev, v = fa.get_eigenvalues()
ev
# Out:
# array([ 1.12390276e+01,  6.91616537e+00,  2.92312629e+00,  1.80148499e+00,
#         1.41930241e+00,  1.06954242e+00,  7.87139122e-01,  6.02139459e-01,
#         3.88641400e-01,  3.69150577e-01,  2.77332942e-01,  2.57228199e-01,
#         2.02348201e-01,  1.57454710e-01,  1.32894592e-01,  1.13922844e-01,
#         9.67665325e-02,  8.33400873e-02,  5.67632164e-02,  3.85418904e-02,
#         2.66112538e-02,  1.97251320e-02,  1.29790010e-02,  6.27460582e-03,
#         2.09717342e-03,  5.36265327e-16,  1.49356754e-16, -2.35404600e-16,
#        -5.58793398e-16])

# %% [markdown]
# Endast 6 av dessa eigenvärden är större än 1.

# %%
np.count_nonzero(ev>1)
# Out:
# 6

# %% [markdown]
# Undersök nu Scree-ploten för att se att den nionde faktorn är mindre än 1.

# %%
fig = plt.figure(figsize = (12, 7))

ax = plt.axes()

x = range(1, data.shape[1]+1)

y = ev

ax.plot(x, y, 'o', color ='orange', linestyle = 'solid', label = 'Eigenvärde')

ax.axhline(y = 1, color = 'orange', linestyle = 'dashed', label = 'y = 1')

ax.set_xlabel('Faktorer', fontsize = 20)

ax.set_title("Scree plot", fontsize = 40)

ax.legend(fancybox=True, framealpha=1, shadow=True, borderpad=1, prop=dict(size=18))

import seaborn as sns
sns.set()

# %% [markdown]
# ***
# ## <a id = "3.5">3.5 Faktorladdningar</a>
# Undersök faktorladdningarna.

# %%
fa = FactorAnalyzer(n_factors = 6, rotation = 'varimax', method = 'principal')

fa.fit(data) 

laddningar = pd.DataFrame.from_records(fa.loadings_)

laddningar = laddningar.set_index(data.columns)  

laddningar = laddningar.round(2)

laddningar.columns = ['Faktor 1', 'Faktor 2', 'Faktor 3', 'Faktor 4', 'Faktor 5', 'Faktor 6']

# %% [markdown]
# Det är ett stort antal variabler. Färgkoda laddningarna för att enklare se vilken riktning de har. Negativa laddningar är röda och positiva laddningar är gröna. Det går även att bortse från laddningar som mindre (större) än 0.3 (-0.3) för att tydligare se mönster.

# %%
laddningar1 = laddningar[(laddningar > 0.3) | (laddningar < -0.3)]

def färg(laddning):
  if laddning < 0:
    color = 'red'
  elif laddning > 0:
    color = 'green'
  else:
    color = 'grey'

  return 'color: %s' % color
 
laddningar1.style.applymap(färg)
# Out:
# <style  type="text/css" >
#     #T_d70f1f58_fbbf_11e9_aad6_b4692127e7f9row0_col0 {
#             color:  green;
#         }    #T_d70f1f58_fbbf_11e9_aad6_b4692127e7f9row0_col1 {
#             color:  grey;
#         }    #T_d70f1f58_fbbf_11e9_aad6_b4692127e7f9row0_col2 {
#             color:  grey;
#         }    #T_d70f1f58_fbbf_11e9_aad6_b4692127e7f9row0_col3 {
#             color:  red;
#         }    #T_d70f1f58_fbbf_11e9_aad6_b4692127e7f9row0_col4 {
#             color:  grey;
#         }    #T_d70f1f58_fbbf_11e9_aad6_b4692127e7f9row0_col5 {
#             color:  grey;
#         }    #T_d70f1f58_fbbf_11e9_aad6_b4692127e7f9row1_col0 {
#             color:  grey;
#         }    #T_d70f1f58_fbbf_11e9_aad6_b4692127e7f9row1_col1 {
#             color:  green;
#         }    #T_d70f1f58_fbbf_11e9_aad6_b4692127e7f9row1_col2 {
#             color:  grey;
#         }    #T_d70f1f58_fbbf_11e9_aad6_b4692127e7f9row1_col3 {
#             color:  red;
#         }    #T_d70f1f58_fbbf_11e9_aad6_b4692127e7f9row1_col4 {
#             color:  grey;
#         }    #T_d70f1f58_fbbf_11e9_aad6_b4692127e7f9row1_col5 {
#             color:  grey;
#         }    #T_d70f1f58_fbbf_11e9_aad6_b4692127e7f9row2_col0 {
#             color:  red;
#         }    #T_d70f1f58_fbbf_11e9_aad6_b4692127e7f9row2_col1 {
#             color:  grey;
#         }    #T_d70f1f58_fbbf_11e9_aad6_b4692127e7f9row2_col2 {
#             color:  grey;
#         }    #T_d70f1f58_fbbf_11e9_aad6_b4692127e7f9row2_col3 {
#             color:  grey;
#         }    #T_d70f1f58_fbbf_11e9_aad6_b4692127e7f9row2_col4 {
#             color:  grey;
#         }    #T_d70f1f58_fbbf_11e9_aad6_b4692127e7f9row2_col5 {
#             color:  grey;
#         }    #T_d70f1f58_fbbf_11e9_aad6_b4692127e7f9row3_col0 {
#             color:  red;
#         }    #T_d70f1f58_fbbf_11e9_aad6_b4692127e7f9row3_col1 {
#             color:  grey;
#         }    #T_d70f1f58_fbbf_11e9_aad6_b4692127e7f9row3_col2 {
#             color:  grey;
#         }    #T_d70f1f58_fbbf_11e9_aad6_b4692127e7f9row3_col3 {
#             color:  green;
#         }    #T_d70f1f58_fbbf_11e9_aad6_b4692127e7f9row3_col4 {
#             color:  grey;
#         }    #T_d70f1f58_fbbf_11e9_aad6_b4692127e7f9row3_col5 {
#             color:  grey;
#         }    #T_d70f1f58_fbbf_11e9_aad6_b4692127e7f9row4_col0 {
#             color:  green;
#         }    #T_d70f1f58_fbbf_11e9_aad6_b4692127e7f9row4_col1 {
#             color:  grey;
#         }    #T_d70f1f58_fbbf_11e9_aad6_b4692127e7f9row4_col2 {
#             color:  grey;
#         }    #T_d70f1f58_fbbf_11e9_aad6_b4692127e7f9row4_col3 {
#             color:  grey;
#         }    #T_d70f1f58_fbbf_11e9_aad6_b4692127e7f9row4_col4 {
#             color:  grey;
#         }    #T_d70f1f58_fbbf_11e9_aad6_b4692127e7f9row4_col5 {
#             color:  grey;
#         }    #T_d70f1f58_fbbf_11e9_aad6_b4692127e7f9row5_col0 {
#             color:  red;
#         }    #T_d70f1f58_fbbf_11e9_aad6_b4692127e7f9row5_col1 {
#             color:  grey;
#         }    #T_d70f1f58_fbbf_11e9_aad6_b4692127e7f9row5_col2 {
#             color:  grey;
#         }    #T_d70f1f58_fbbf_11e9_aad6_b4692127e7f9row5_col3 {
#             color:  green;
#         }    #T_d70f1f58_fbbf_11e9_aad6_b4692127e7f9row5_col4 {
#             color:  grey;
#         }    #T_d70f1f58_fbbf_11e9_aad6_b4692127e7f9row5_col5 {
#             color:  grey;
#         }    #T_d70f1f58_fbbf_11e9_aad6_b4692127e7f9row6_col0 {
#             color:  green;
#         }    #T_d70f1f58_fbbf_11e9_aad6_b4692127e7f9row6_col1 {
#             color:  grey;
#         }    #T_d70f1f58_fbbf_11e9_aad6_b4692127e7f9row6_col2 {
#             color:  grey;
#         }    #T_d70f1f58_fbbf_11e9_aad6_b4692127e7f9row6_col3 {
#             color:  grey;
#         }    #T_d70f1f58_fbbf_11e9_aad6_b4692127e7f9row6_col4 {
#             color:  grey;
#         }    #T_d70f1f58_fbbf_11e9_aad6_b4692127e7f9row6_col5 {
#             color:  green;
#         }    #T_d70f1f58_fbbf_11e9_aad6_b4692127e7f9row7_col0 {
#             color:  red;
#         }    #T_d70f1f58_fbbf_11e9_aad6_b4692127e7f9row7_col1 {
#             color:  green;
#         }    #T_d70f1f58_fbbf_11e9_aad6_b4692127e7f9row7_col2 {
#             color:  grey;
#         }    #T_d70f1f58_fbbf_11e9_aad6_b4692127e7f9row7_col3 {
#             color:  red;
#         }    #T_d70f1f58_fbbf_11e9_aad6_b4692127e7f9row7_col4 {
#             color:  grey;
#         }    #T_d70f1f58_fbbf_11e9_aad6_b4692127e7f9row7_col5 {
#             color:  grey;
#         }    #T_d70f1f58_fbbf_11e9_aad6_b4692127e7f9row8_col0 {
#             color:  green;
#         }    #T_d70f1f58_fbbf_11e9_aad6_b4692127e7f9row8_col1 {
#             color:  grey;
#         }    #T_d70f1f58_fbbf_11e9_aad6_b4692127e7f9row8_col2 {
#             color:  green;
#         }    #T_d70f1f58_fbbf_11e9_aad6_b4692127e7f9row8_col3 {
#             color:  green;
#         }    #T_d70f1f58_fbbf_11e9_aad6_b4692127e7f9row8_col4 {
#             color:  grey;
#         }    #T_d70f1f58_fbbf_11e9_aad6_b4692127e7f9row8_col5 {
#             color:  grey;
#         }    #T_d70f1f58_fbbf_11e9_aad6_b4692127e7f9row9_col0 {
#             color:  grey;
#         }    #T_d70f1f58_fbbf_11e9_aad6_b4692127e7f9row9_col1 {
#             color:  red;
#         }    #T_d70f1f58_fbbf_11e9_aad6_b4692127e7f9row9_col2 {
#             color:  green;
#         }    #T_d70f1f58_fbbf_11e9_aad6_b4692127e7f9row9_col3 {
#             color:  green;
#         }    #T_d70f1f58_fbbf_11e9_aad6_b4692127e7f9row9_col4 {
#             color:  grey;
#         }    #T_d70f1f58_fbbf_11e9_aad6_b4692127e7f9row9_col5 {
#             color:  grey;
#         }    #T_d70f1f58_fbbf_11e9_aad6_b4692127e7f9row10_col0 {
#             color:  green;
#         }    #T_d70f1f58_fbbf_11e9_aad6_b4692127e7f9row10_col1 {
#             color:  grey;
#         }    #T_d70f1f58_fbbf_11e9_aad6_b4692127e7f9row10_col2 {
#             color:  green;
#         }    #T_d70f1f58_fbbf_11e9_aad6_b4692127e7f9row10_col3 {
#             color:  grey;
#         }    #T_d70f1f58_fbbf_11e9_aad6_b4692127e7f9row10_col4 {
#             color:  grey;
#         }    #T_d70f1f58_fbbf_11e9_aad6_b4692127e7f9row10_col5 {
#             color:  grey;
#         }    #T_d70f1f58_fbbf_11e9_aad6_b4692127e7f9row11_col0 {
#             color:  green;
#         }    #T_d70f1f58_fbbf_11e9_aad6_b4692127e7f9row11_col1 {
#             color:  grey;
#         }    #T_d70f1f58_fbbf_11e9_aad6_b4692127e7f9row11_col2 {
#             color:  green;
#         }    #T_d70f1f58_fbbf_11e9_aad6_b4692127e7f9row11_col3 {
#             color:  grey;
#         }    #T_d70f1f58_fbbf_11e9_aad6_b4692127e7f9row11_col4 {
#             color:  grey;
#         }    #T_d70f1f58_fbbf_11e9_aad6_b4692127e7f9row11_col5 {
#             color:  grey;
#         }    #T_d70f1f58_fbbf_11e9_aad6_b4692127e7f9row12_col0 {
#             color:  green;
#         }    #T_d70f1f58_fbbf_11e9_aad6_b4692127e7f9row12_col1 {
#             color:  grey;
#         }    #T_d70f1f58_fbbf_11e9_aad6_b4692127e7f9row12_col2 {
#             color:  grey;
#         }    #T_d70f1f58_fbbf_11e9_aad6_b4692127e7f9row12_col3 {
#             color:  grey;
#         }    #T_d70f1f58_fbbf_11e9_aad6_b4692127e7f9row12_col4 {
#             color:  grey;
#         }    #T_d70f1f58_fbbf_11e9_aad6_b4692127e7f9row12_col5 {
#             color:  grey;
#         }    #T_d70f1f58_fbbf_11e9_aad6_b4692127e7f9row13_col0 {
#             color:  grey;
#         }    #T_d70f1f58_fbbf_11e9_aad6_b4692127e7f9row13_col1 {
#             color:  grey;
#         }    #T_d70f1f58_fbbf_11e9_aad6_b4692127e7f9row13_col2 {
#             color:  grey;
#         }    #T_d70f1f58_fbbf_11e9_aad6_b4692127e7f9row13_col3 {
#             color:  grey;
#         }    #T_d70f1f58_fbbf_11e9_aad6_b4692127e7f9row13_col4 {
#             color:  grey;
#         }    #T_d70f1f58_fbbf_11e9_aad6_b4692127e7f9row13_col5 {
#             color:  green;
#         }    #T_d70f1f58_fbbf_11e9_aad6_b4692127e7f9row14_col0 {
#             color:  green;
#         }    #T_d70f1f58_fbbf_11e9_aad6_b4692127e7f9row14_col1 {
#             color:  grey;
#         }    #T_d70f1f58_fbbf_11e9_aad6_b4692127e7f9row14_col2 {
#             color:  grey;
#         }    #T_d70f1f58_fbbf_11e9_aad6_b4692127e7f9row14_col3 {
#             color:  grey;
#         }    #T_d70f1f5

# %% [markdown]
# ***
# ## <a id = "3.6">3.6 Kumulativ varians</a>
# Den kumulativa variansen säger att åtta faktorer förklarar ungefär 87% av variansen i data. Den första faktorn förklara 26% medan den åttonde endast förklarar 4%.

# %%
fa.get_factor_variance()

kumulativ = pd.DataFrame.from_records(fa.get_factor_variance()).iloc[1:, :]

Statistik = (['Förklarad varians per faktor', 'Kumulativ förklarad varians'])  

kumulativ['Statistik'] = Statistik

kumulativ = kumulativ.set_index('Statistik')  

kumulativ.columns = ['Faktor 1', 'Faktor 2', 'Faktor 3', 'Faktor 4', 'Faktor 5', 'Faktor 6']  

kumulativ.round(2)
# Out:
#                               Faktor 1  Faktor 2  Faktor 3  Faktor 4  \
# Statistik
# Förklarad varians per faktor      0.31      0.21      0.12      0.11
# Kumulativ förklarad varians       0.31      0.51      0.64      0.74
#
#                               Faktor 5  Faktor 6
# Statistik
# Förklarad varians per faktor      0.07      0.07
# Kumulativ förklarad varians       0.81      0.87

# %% [markdown]
# ***
# # <a id = "4">4. Referenser</a>
# * Costello, Anna B. & Jason Osborne (2005). Best practices in exploratory factor analysis: four
# recommendations for getting the most from your analysis. Practical Assessment Research & Evaluation, 10(7).
# Available online: http://pareonline.net/getvn.asp?v=10&n=7
#
#
# * [FactorAnalyzer](https://factor-analyzer.readthedocs.io/en/latest/factor_analyzer.html)

# %% [markdown]
# ***
# **Kontakt:** [Marcus Brafors](https://www.su.se/profiles/mabr4821-1.403903)

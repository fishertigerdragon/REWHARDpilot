# %% [markdown]
# # <span style="color:mediumslateblue; font-family:freestyle script; font-size:4em">Harmonisering:</span> <br><span style="color:greenyellow; font-family:freestyle script; font-size:4em">Faktoranalys</span>
# ***

# %% [markdown]
# # Innehållsförteckning
# 1. [Importera bibliotek](#1)
# 2. [Importera data](#2)
# 3. [Faktoranalys](#3)
#     3.1 [Bartlett](#3.1)
#     3.2 [Shapiro-Wilk](#3.2)
#     3.3 [Rotation](#3.3)
#     3.4 [Antal faktorer](#3.4)
#     3.5 [Faktorladdningar](#3.5)
#     3.6 [Kumulativ varians](#3.6)
# 4. [Referenser](#4)
# ***

# %% [markdown]
# # <a id = "1">1. Importera bibliotek</a>
# De bibliotek som behövs i det här skriptet är **pandas**, **numpy**, **matplotlib.pyplot** och **FactorAnalyzer**.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from factor_analyzer import FactorAnalyzer

# %% [markdown]
# ***
# # <a id = "2">2. Importera data</a>
# Läs in data från excelfil.

# %%
data = pd.read_excel('SLOSH och LNU medelvärden och n per SSYK för harmonisering.xlsx')
data.head(5)
# Out:
#    SSYK  z670_mean  z670_count  z671_mean  z671_count  z672_mean  z672_count  \
# 0     9        1.4       319.0        1.6       318.0        1.1       319.0
# 1    11        2.0        11.0        2.0        11.0        1.2        11.0
# 2    12        1.8       123.0        1.8       123.0        1.0       123.0
# 3    13        1.4        22.0        1.8        22.0        1.1        22.0
# 4    14        NaN         NaN        NaN         NaN        NaN         NaN
#
#    z673_mean  z673_count  z674_mean  ...  Workinge_mean  Workinge_count  \
# 0        1.7         3.0        2.7  ...            4.0             1.0
# 1        2.5        11.0        2.5  ...            3.6            78.0
# 2        1.9       123.0        2.4  ...            3.5           280.0
# 3        1.8        22.0        2.0  ...            3.5           323.0
# 4        NaN         NaN        NaN  ...            3.8            96.0
#
#    Worklear_mean  Worklear_count  Workrepe_mean  Workrepe_count  Workhow_mean  \
# 0            4.0             1.0            4.0             1.0           4.0
# 1            3.5            78.0            2.5            78.0           3.6
# 2            3.4           280.0            2.5           285.0           3.7
# 3            3.4           322.0            2.6           326.0           3.7
# 4            3.6            96.0            2.4            97.0           3.7
#
#    Workhow_count  Workwhat_mean  Workwhat_count
# 0            1.0            2.0             1.0
# 1           78.0            3.2            78.0
# 2          284.0            3.3           285.0
# 3          326.0            3.3           326.0
# 4           96.0            3.2            96.0
#
# [5 rows x 71 columns]

# %% [markdown]
# Använd SSYK-variabeln som index och ta bort de variabler som visar antal observationer (alltså varannan variabel).

# %%
data = data.set_index('SSYK')

data = data[data.columns[::2]]  

data.head(5)
# Out:
#       z670_mean  z671_mean  z672_mean  z673_mean  z674_mean  z680_mean  \
# SSYK
# 9           1.4        1.6        1.1        1.7        2.7        3.4
# 11          2.0        2.0        1.2        2.5        2.5        3.3
# 12          1.8        1.8        1.0        1.9        2.4        3.3
# 13          1.4        1.8        1.1        1.8        2.0        3.3
# 14          NaN        NaN        NaN        NaN        NaN        NaN
#
#       z681_mean  z682_mean  z616_mean  z624_mean  ...  Workhard_mean  \
# SSYK                                              ...
# 9           3.8        4.4        1.0        2.0  ...            3.0
# 11          3.3        4.1        1.1        1.9  ...            2.9
# 12          4.4        4.1        1.0        1.9  ...            2.9
# 13          3.5        4.5        1.2        1.4  ...            2.8
# 14          NaN        NaN        NaN        NaN  ...            2.9
#
#       Workeffo_mean  Worktime_mean  Workcntr_mean  Workskil_mean  \
# SSYK
# 9               3.0            4.0            2.0            4.0
# 11              2.8            2.8            2.7            3.8
# 12              2.8            2.8            2.6            3.7
# 13              2.8            2.9            2.8            3.6
# 14              3.1            2.6            2.9            3.8
#
#       Workinge_mean  Worklear_mean  Workrepe_mean  Workhow_mean  Workwhat_mean
# SSYK
# 9               4.0            4.0            4.0           4.0            2.0
# 11              3.6            3.5            2.5           3.6            3.2
# 12              3.5            3.4            2.5           3.7            3.3
# 13              3.5            3.4            2.6           3.7            3.3
# 14              3.8            3.6            2.4           3.7            3.2
#
# [5 rows x 35 columns]

# %% [markdown]
# ***
# # <a id = "3">3. Faktoranalys</a>
# Bartlett:s test genomförs för att se ifall det är lämpligt att utföra en faktoranalys på data. Vilken metod som är lämpligast för att utvinna faktorer avgörs av huruvida data är normalfördelad. Analysen kommer använda en oblique rotationsmetod. Antal faktorer som analysen ska omfatta fastställs med hjälp av Kaiser-kriteriet. Till sist analyseras faktorladdningarna och den kumulativa variansen.

# %% [markdown]
# ***
# ## <a id = "3.1">3.1 Bartlett</a>
# Tester visar ifall variablerna kovarierar över huvudtaget. Om resultat är statistiskt signifikant kovarierar variablerna och det är lämpligt att fortsätta med faktoranalysen
# [Läs mer om testet här](https://www.statisticshowto.datasciencecentral.com/bartletts-test/)

# %%
datatest = data.dropna()

from factor_analyzer.factor_analyzer import calculate_bartlett_sphericity  

chi_square_value,p = calculate_bartlett_sphericity(datatest)

chi_square_value, p

alpha = 0.05

if p > alpha:
    print('Variablerna samvarierar inte (H0)')
else:
    print('Variablerna samvarierar (förkasta H0)')
# Out:
# Variablerna samvarierar (förkasta H0)

# %% [markdown]
# ***
# ## <a id = "3.2">3.2 Shapiro-Wilk</a>
# Undersök huruvida data är normalfördelad. Testet som används är Shapiro-Wilk, nollhypotesen säger att data är normalfördelad.
#
# [Läs mer om testet här](https://www.statisticshowto.datasciencecentral.com/shapiro-wilk-test/)

# %%
from scipy.stats import shapiro

stat, p = shapiro(data)

alpha = 0.05

if p > alpha:
    print('Data verkar normalfördelad (H0)')
else:
    print('Data verkar inte normalfördelad (förkasta H0)')
# Out:
# Data verkar normalfördelad (H0)

# %% [markdown]
# ***
# ## <a id = "3.3">3.3 Rotation</a>
# Faktoranalysen kommer använda en oblique rotation. Ortogonal rotation är lämpligt då faktorerna inte är korrelerade med varandra. Oblique rotation tillåter att faktorerna är korrelerade. Läs mer om val av metod för rotation i "Best Practices in Exploratory Factor Analysis: Four Recommendations for Getting the Most From Your Analysis " av Anna B. Costello och Jason W. Osborne.
# >In the social sciences we generally expect some correlation among factors, since behavior is rarely partitioned into neatly packaged units that function independently of one another (s. 3)

# %% [markdown]
# ***
# ## <a id = "3.4">3.4 Antal faktorer</a>
# För att ta ställning till vilket antal faktorer som är lämpligt kommer Kaiser-kriteriet tillsammans med en Scree-plot användas. Kaiser-kritieriet säger att endast de faktorer med eigenvärde större än 1 är lämpliga. Börja med att inkludera ett stort antal faktorer.

# %%
fa = FactorAnalyzer(n_factors = 25, rotation = 'promax', method = 'ml')

fa.fit(data)
# Out:
# FactorAnalyzer(bounds=(0.005, 1), impute='median', is_corr_matrix=False,
#         method='ml', n_factors=25, rotation='promax', rotation_kwargs={},
#         use_smc=True)

# %% [markdown]
# Ta fram egenvärden.

# %%
ev, v = fa.get_eigenvalues()
ev
# Out:
# array([1.17679312e+01, 6.56429892e+00, 3.61419520e+00, 2.37004982e+00,
#        1.93935265e+00, 1.55021217e+00, 1.33641707e+00, 1.03172998e+00,
#        8.71325822e-01, 6.13081915e-01, 4.97569308e-01, 4.41610360e-01,
#        3.83224711e-01, 3.30289395e-01, 2.73180704e-01, 2.03984901e-01,
#        1.82523599e-01, 1.62678570e-01, 1.50413562e-01, 1.35915130e-01,
#        1.14813042e-01, 1.02964207e-01, 7.29729986e-02, 7.02644352e-02,
#        5.19598766e-02, 3.52451479e-02, 3.25548281e-02, 2.96235342e-02,
#        2.22502489e-02, 1.69648241e-02, 1.38766204e-02, 7.75227286e-03,
#        5.01840414e-03, 2.73414393e-03, 1.02045058e-03])

# %% [markdown]
# Antalet eigenvärden större än 1 är 8.

# %%
np.count_nonzero(ev>1)
# Out:
# 8

# %% [markdown]
# Undersök nu Scree-ploten för att se att den nionde faktorn är mindre än 1.

# %%
plt.figure(figsize=(15, 7))
plt.scatter(range(1,data.shape[1]+1),ev)
plt.plot(range(1,data.shape[1]+1),ev)
plt.yticks(np.arange(min(ev), max(ev)+1, 1.0))
plt.title('Scree Plot')
plt.xlabel('Factorer')
plt.ylabel('Eigenvärde')
plt.grid()
plt.show()

# %% [markdown]
# ***
# ## <a id = "3.5">3.5 Faktorladdningar</a>
# Undersök faktorladdningarna.

# %%
fa = FactorAnalyzer(n_factors = 8, rotation = 'promax', method = 'ml')

fa.fit(data) 

laddningar = pd.DataFrame.from_records(fa.loadings_)

laddningar = laddningar.set_index(data.columns)  

laddningar
# Out:
#                       0         1         2         3         4         5  \
# z670_mean      0.383957  0.070975 -0.114284  0.837365 -0.104409  0.077607
# z671_mean      0.131635  0.167887 -0.165489  0.512746 -0.095788  0.060638
# z672_mean     -1.046487 -0.098749  0.143273  0.023473  0.074369 -0.011759
# z673_mean     -0.203308 -0.031718  0.004932  1.065489 -0.013888  0.011483
# z674_mean      0.601275 -0.030341  0.033288  0.179726  0.025817 -0.064047
# z680_mean     -0.689418 -0.082655  0.043214 -0.384580  0.023574  0.029558
# z681_mean      0.956819  0.077500 -0.042814  0.237983 -0.106440 -0.023924
# z682_mean     -0.332941  0.150683 -0.095878 -0.829864 -0.034951 -0.045378
# z616_mean     -0.546776  0.062405 -0.058299  0.199282 -0.092724 -0.048131
# z624_mean      1.013816 -0.079005 -0.048490  0.137021  0.014071 -0.029543
# z647_mean      0.859594  0.112238  0.031014 -0.116737  0.015439 -0.046493
# z651_mean     -0.432428  0.072466  0.022652  0.423788  0.097375  0.151940
# z626_mean      0.733757  0.107606 -0.150792 -0.382265 -0.117524  0.125327
# z652_mean      0.299246 -0.054804 -0.142174 -0.846405  0.036351  0.037714
# z653_mean      0.527031 -0.005619  0.198676 -0.132800  0.106758  0.192840
# z654_mean      0.834729  0.039093 -0.080476 -0.178576  0.025218  0.188216
# z655_mean      1.078449  0.013348 -0.104425 -0.038892 -0.047479 -0.007542
# z656_mean      0.438166 -0.185670  0.182731 -0.158544  0.028457 -0.105442
# z625_mean      0.761250 -0.026226  0.110242  0.373755  0.013444 -0.147920
# z621_mean     -0.139267  0.486217 -0.306800 -0.121321 -0.263054  0.266515
# z622_mean      0.123608 -0.273131  0.250905  0.070021  0.139923 -0.156852
# Loadtime_mean  0.093898  0.866586 -0.217556 -0.029192  0.476110 -0.131231
# Interrup_mean -0.054409  1.012016  0.289950 -0.037165 -0.121024 -0.069092
# Morework_mean  0.058222  0.893595 -0.247339  0.046965  0.043134  0.094144
# Workfast_mean -0.096859  0.620833 -0.345405  0.061972  0.386851  0.100562
# Workhard_mean -0.004261 -0.121801 -0.269391 -0.043547  0.892081  0.239457
# Workeffo_mean -0.002352  0.355093  0.285489 -0.038492  0.726194 -0.170622
# Worktime_mean -0.049583 -0.753545 -0.090830 -0.078992 -0.062454 -0.152172
# Workcntr_mean  0.105231  0.880931  0.325379 -0.141526 -0.042885 -0.206487
# Workskil_mean  0.324607 -0.075397  0.572829  0.124880  0.188027  0.200772
# Workinge_mean -0.040594  0.033227  1.015966  0.003339 -0.014153  0.145837
# Worklear_mean -0.150183  0.214113  1.099590  0.050438 -0.129657 -0.036369
# Workrepe_mean -0.083804 -0.611030 -0.596915  0.030714  0.223640 -0.218520
# Workhow_mean  -0.026216 -0.190380  0.694355 -0.012145  0.070139  0.561154
# Workwhat_mean  0.094017  0.065453  0.286895  0.084074  0.082355  0.945318
#
#                       6         7
# z670_mean     -0.268391  0.306220
# z671_mean      0.233760  0.625408
# z672_mean     -0.163375 -0.002862
# z673_mean     -0.116038  0.349653
# z674_mean     -0.096308  0.388859
# z680_mean     -0.131041 -0.222927
# z681_mean     -0.170092 -0.388711
# z682_mean      0.033209  0.112312
# z616_mean     -0.113565  0.025179
# z624_mean      0.208442 -0.096195
# z647_mean      0.218021  0.075442
# z651_mean      0.238267  0.000910
# z626_mean     -0.371985 -0.028260
# z652_mean      0.038352  0.162904
# z653_mean     -0.226076 -0.005586
# z654_mean      0.191177  0.255751
# z655_mean      0.378295  0.030969
# z656_mean      0.878704  0.089037
# z625_mean     -0.177382 -0.105209
# z621_mean      0.021125 -0.171172
# z622_mean     -0.157174  0.468147
# Loadtime_mean -0.028985  0.074967
# Interrup_mean -0.017053  0.006281
# Morework_mean -0.123882  0.002166
# Workfast_mean -0.105167 -0.114292
# Workhard_mean  0.009455 -0.034394
# Workeffo_mean  0.060517  0.050044
# Worktime_mean  0.139366 -0.036791
# Workcntr_mean  0.008305 -0.036880
# Workskil_mean  0.148215 -0.106855
# Workinge_mean  0.125606 -0.083989
# Worklear_mean  0.105035  0.007973
# Workrepe_mean -0.002663 -0.081444
# Workhow_mean  -0.088107  0.115163
# Workwhat_mean -0.126353 -0.036418

# %% [markdown]
# Det går att isolera de laddningar som antingen är större än 0.5 eller mindre än -0.5

# %%
laddningar[(laddningar > 0.5) | (laddningar < -0.5)]
# Out:
#                       0         1         2         3         4         5  \
# z670_mean           NaN       NaN       NaN  0.837365       NaN       NaN
# z671_mean           NaN       NaN       NaN  0.512746       NaN       NaN
# z672_mean     -1.046487       NaN       NaN       NaN       NaN       NaN
# z673_mean           NaN       NaN       NaN  1.065489       NaN       NaN
# z674_mean      0.601275       NaN       NaN       NaN       NaN       NaN
# z680_mean     -0.689418       NaN       NaN       NaN       NaN       NaN
# z681_mean      0.956819       NaN       NaN       NaN       NaN       NaN
# z682_mean           NaN       NaN       NaN -0.829864       NaN       NaN
# z616_mean     -0.546776       NaN       NaN       NaN       NaN       NaN
# z624_mean      1.013816       NaN       NaN       NaN       NaN       NaN
# z647_mean      0.859594       NaN       NaN       NaN       NaN       NaN
# z651_mean           NaN       NaN       NaN       NaN       NaN       NaN
# z626_mean      0.733757       NaN       NaN       NaN       NaN       NaN
# z652_mean           NaN       NaN       NaN -0.846405       NaN       NaN
# z653_mean      0.527031       NaN       NaN       NaN       NaN       NaN
# z654_mean      0.834729       NaN       NaN       NaN       NaN       NaN
# z655_mean      1.078449       NaN       NaN       NaN       NaN       NaN
# z656_mean           NaN       NaN       NaN       NaN       NaN       NaN
# z625_mean      0.761250       NaN       NaN       NaN       NaN       NaN
# z621_mean           NaN       NaN       NaN       NaN       NaN       NaN
# z622_mean           NaN       NaN       NaN       NaN       NaN       NaN
# Loadtime_mean       NaN  0.866586       NaN       NaN       NaN       NaN
# Interrup_mean       NaN  1.012016       NaN       NaN       NaN       NaN
# Morework_mean       NaN  0.893595       NaN       NaN       NaN       NaN
# Workfast_mean       NaN  0.620833       NaN       NaN       NaN       NaN
# Workhard_mean       NaN       NaN       NaN       NaN  0.892081       NaN
# Workeffo_mean       NaN       NaN       NaN       NaN  0.726194       NaN
# Worktime_mean       NaN -0.753545       NaN       NaN       NaN       NaN
# Workcntr_mean       NaN  0.880931       NaN       NaN       NaN       NaN
# Workskil_mean       NaN       NaN  0.572829       NaN       NaN       NaN
# Workinge_mean       NaN       NaN  1.015966       NaN       NaN       NaN
# Worklear_mean       NaN       NaN  1.099590       NaN       NaN       NaN
# Workrepe_mean       NaN -0.611030 -0.596915       NaN       NaN       NaN
# Workhow_mean        NaN       NaN  0.694355       NaN       NaN  0.561154
# Workwhat_mean       NaN       NaN       NaN       NaN       NaN  0.945318
#
#                       6         7
# z670_mean           NaN       NaN
# z671_mean           NaN  0.625408
# z672_mean           NaN       NaN
# z673_mean           NaN       NaN
# z674_mean           NaN       NaN
# z680_mean           NaN       NaN
# z681_mean           NaN       NaN
# z682_mean           NaN       NaN
# z616_mean           NaN       NaN
# z624_mean           NaN       NaN
# z647_mean           NaN       NaN
# z651_mean           NaN       NaN
# z626_mean           NaN       NaN
# z652_mean           NaN       NaN
# z653_mean           NaN       NaN
# z654_mean           NaN       NaN
# z655_mean           NaN       NaN
# z656_mean      0.878704       NaN
# z625_mean           NaN       NaN
# z621_mean           NaN       NaN
# z622_mean           NaN       NaN
# Loadtime_mean       NaN       NaN
# Interrup_mean       NaN       NaN
# Morework_mean       NaN       NaN
# Workfast_mean       NaN       NaN
# Workhard_mean       NaN       NaN
# Workeffo_mean       NaN       NaN
# Worktime_mean       NaN       NaN
# Workcntr_mean       NaN       NaN
# Workskil_mean       NaN       NaN
# Workinge_mean       NaN       NaN
# Worklear_mean       NaN       NaN
# Workrepe_mean       NaN       NaN
# Workhow_mean        NaN       NaN
# Workwhat_mean       NaN       NaN

# %% [markdown]
# ***
# ## <a id = "3.6">3.6 Kumulativ varians</a>
# Den kumulativa variansen säger att åtta faktorer förklarar ungefär 87% av variansen i data. Den första faktorn förklara 26% medan den åttonde endast förklarar 4%.

# %%
fa.get_factor_variance()

kumulativ = pd.DataFrame.from_records(fa.get_factor_variance()).iloc[1:, :]

Statistik = (['Förklarad varians per faktor', 'Kumulativ förklarad varians'])  

kumulativ['Statistik'] = Statistik

kumulativ = kumulativ.set_index('Statistik')  

kumulativ
# Out:
#                                      0         1         2         3  \
# Statistik
# Förklarad varians per faktor  0.262086  0.153752  0.127283  0.126840
# Kumulativ förklarad varians   0.262086  0.415838  0.543121  0.669961
#
#                                      4         5         6         7
# Statistik
# Förklarad varians per faktor  0.057517  0.050767  0.048760  0.040384
# Kumulativ förklarad varians   0.727478  0.778245  0.827005  0.867389

# %% [markdown]
# ***
# # <a id = "4">4. Referenser</a>
# * Costello, Anna B. & Jason Osborne (2005). Best practices in exploratory factor analysis: four
# recommendations for getting the most from your analysis. Practical Assessment Research & Evaluation, 10(7).
# Available online: http://pareonline.net/getvn.asp?v=10&n=7
#
#
# * [FactorAnalyzer](https://factor-analyzer.readthedocs.io/en/latest/factor_analyzer.html)

# %% [markdown]
# ***
# **Kontakt:** [Marcus Brafors](https://www.su.se/profiles/mabr4821-1.403903)
